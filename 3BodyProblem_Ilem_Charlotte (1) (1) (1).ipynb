# %% [markdown]
# #### <span style="color:black">Research and stuff</span>
#
# https://en.wikipedia.org/wiki/Three-body_problem
#
# https://www.scirp.org/pdf/AM20120900021_79808753.pdf
#
# http://www.scholarpedia.org/article/Three_body_problem

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp  # the differential equation integrator

plt.rcParams["figure.figsize"] = (12,8)  # make figures big for easier viewing
                                         #    (width, height in inches)

# To revert to the small default size uncomment the following line
# plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

from matplotlib import animation    # animation package (for later)
from IPython.display import HTML    # for displaying animation inline
import triplebody as trpb           #importing the code we write using a derivative function and solve_ivp (see over file)

# %%
#Parameters are now defined as x1i,x2i,...x_dot1i,x_dot2i to differentiate them from parameters of deriv
trpb.plot(t_max = 50, x1i = 50, y1i = 100, x2i = -80, y3i = 50, m1 = 10**15, m2 = 10**17, m3 = 10**14, x_dot1i = -5, y_dot3i=-20)
# Out:
# (<Figure size 1200x800 with 6 Axes>,
#  <Figure size 1200x800 with 6 Axes>,
#  <Figure size 1200x800 with 1 Axes>)
